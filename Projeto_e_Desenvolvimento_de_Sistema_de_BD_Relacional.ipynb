# %% [markdown]
# <a href="https://colab.research.google.com/github/RafaBBoaventura/Projeto-e-Desenvolvimento-de-Sistema-de-Banco-de-Dados-Relacional/blob/main/Projeto_e_Desenvolvimento_de_Sistema_de_BD_Relacional.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Projeto - 5º Etapa

# %% [markdown]
# ENTREGAS:
#
# 1° - converter as tabelas do banco de dados em dataframes para operações em Python como as consultas (queries) presentes nas etapas anteriores.
#
# 2° - Entregar um notebook em Python, no formato .ipynb contendo a codificação para fazer as conversões e relatar as dificuldades encontradas, bem como as alternativas adotadas para enfrentá-las.

# %% [markdown]
# ## Importar biblioteca

# %%
import pandas as pd 

import plotly.express as px

# %%
#DataFrame - Importando os dados e listando os arquivos 

dados_df = pd.read_excel("/content/drive/MyDrive/BD.xlsx")

display(dados_df)
# Out:
#                 Banco  IDAgencia  IDAtende Data_Atendimento  Valor_Servico  \
# 0                 PAN          1         1       2022-04-10            100
# 1               Inter          2         2       2022-03-15            150
# 2                 BMG          3         3       2022-01-02            200
# 3              Nubank          4         4       2022-03-15            100
# 4                  C6          5         5       2022-01-01             80
# 5           Santander          6         6       2022-03-08             90
# 6               Itau           7         7       2022-04-10            150
# 7     Caixa ecnomica           8         8       2022-01-02            100
# 8   Branco do brasil           9         9       2022-04-10            200
# 9              Semear         10        10       2022-05-25            100
# 10             Picpay         11        11       2022-04-06            100
# ...

# %% [markdown]
# # Nova seção

# %%
dados_df = pd.read_excel("/content/drive/MyDrive/BD.xlsx")

dados_df.columns.values
# Out:
# array(['Banco', 'IDAgencia', 'IDAtende', 'Data_Atendimento',
#        'Valor_Servico', 'Avaliacao_Servico', 'FK_Atendido_Prestador',
#        'FK_Atende_locatario', 'IDBanco', 'CNPJ_Banco', 'Nome_Banco',
#        'FK_Banco_Locatario', 'IDEnd_Agencia', 'Logradouro_Agencia',
#        'Pais_agencia', 'CEP_agencia', 'Cidade_agencia', 'FK_Num_Agencia',
#        'FK_banco_Parceiro', 'ID_End_Banco', 'Logradouro_Banco',
#        'Pais_Banco', 'CEP_Banco', 'Cidade_Banco', 'FK_End_Banco_Parceiro',
#        'IDEnd_Locador', 'Logradouro_Locador', 'Pais_Locador',
#        'CEP_Locador', 'Cidade_Locador', 'FK_End_Imovel', 'IDFotos_Imovel',
#        'Imagem', 'IDlocador', 'nome_locador', 'CPF_Locador',
#        'IDLocatario', 'Nome_Locatario', 'CPF_Locatario', 'IDPerfilImovel',
#        'Quant_Quarto_disponivel', 'Vaga_Garagem_disponivel',
#        'Quant_Banheiro_disponivel', 'Taman_Area_disponivel',
#        'Valor_Aluguel_disponivel', 'Valor_Condominio_disponivel',
# ...

# %%
#Filtrar somente as colunas que serão usadas

colunas_selecionadas = ['Banco', 'IDAgencia', 'IDAtende', 'Data_Atendimento',
       'Valor_Servico', 'Avaliacao_Servico',
       'IDBanco', 'CNPJ_Banco', 'Nome_Banco',
       'IDEnd_Agencia', 'Logradouro_Agencia',
       'Pais_agencia', 'CEP_agencia', 'Cidade_agencia',
       'ID_End_Banco', 'Logradouro_Banco',
       'Pais_Banco', 'CEP_Banco', 'Cidade_Banco',
       'IDEnd_Locador', 'Logradouro_Locador', 'Pais_Locador',
       'CEP_Locador', 'Cidade_Locador','IDFotos_Imovel',
       'Imagem', 'IDlocador', 'nome_locador', 'CPF_Locador',
       'IDLocatario', 'Nome_Locatario', 'CPF_Locatario', 'IDPerfilImovel',
       'Quant_Quarto_disponivel', 'Vaga_Garagem_disponivel',
       'Quant_Banheiro_disponivel', 'Taman_Area_disponivel',
       'Valor_Aluguel_disponivel', 'Valor_Condominio_disponivel',
       'Valor_IPTU_disponivel','IDPerfil_Locacao',
       'Quant_Quarto_desejado', 'Vagas_Garagem_desejado',
       'Quant_banheiro_desejado', 'Taman_Area_desejado',
       'Valor_Aluguel_desejado', 'Valor_Condominio_desejado',
       'Valor_IPTU_desejado','IDPerfil_Servico',
       'Tipo_Servico', 'Disponibilidade_serviço',
       'IDPessoa_fisica', 'CPF_prestador',
       'IDPessoa_Juridica', 'CNPJ_prestador',
       'IDPrestador', 'nome_prestador', 'IDRecomenda', 'Avaliacao_Imovel',
       'Compatibilidade_Perfil',
       'IDTel_Agencia', 'NumAgencia',
       'IDTel_Banco', 'numbanco',
       'IDTel_Locador', 'numero_Locador',
       'IDTel_Locatario', 'numero_locatario', 'IDTel_Prestador',
       'Numero_prestador']

# %%
dados_df_selecionado = dados_df.filter(items=colunas_selecionadas)

# %%
dados_df_selecionado.head(15)
# Out:
#                 Banco  IDAgencia  IDAtende Data_Atendimento  Valor_Servico  \
# 0                 PAN          1         1       2022-04-10            100
# 1               Inter          2         2       2022-03-15            150
# 2                 BMG          3         3       2022-01-02            200
# 3              Nubank          4         4       2022-03-15            100
# 4                  C6          5         5       2022-01-01             80
# 5           Santander          6         6       2022-03-08             90
# 6               Itau           7         7       2022-04-10            150
# 7     Caixa ecnomica           8         8       2022-01-02            100
# 8   Branco do brasil           9         9       2022-04-10            200
# 9              Semear         10        10       2022-05-25            100
# 10             Picpay         11        11       2022-04-06            100
# ...

# %%
dados_df_selecionado.columns.values
# Out:
# array(['Banco', 'IDAgencia', 'IDAtende', 'Data_Atendimento',
#        'Valor_Servico', 'Avaliacao_Servico', 'IDBanco', 'CNPJ_Banco',
#        'Nome_Banco', 'IDEnd_Agencia', 'Logradouro_Agencia',
#        'Pais_agencia', 'CEP_agencia', 'Cidade_agencia', 'ID_End_Banco',
#        'Logradouro_Banco', 'Pais_Banco', 'CEP_Banco', 'Cidade_Banco',
#        'IDEnd_Locador', 'Logradouro_Locador', 'Pais_Locador',
#        'CEP_Locador', 'Cidade_Locador', 'IDFotos_Imovel', 'Imagem',
#        'IDlocador', 'nome_locador', 'CPF_Locador', 'IDLocatario',
#        'Nome_Locatario', 'CPF_Locatario', 'IDPerfilImovel',
#        'Quant_Quarto_disponivel', 'Vaga_Garagem_disponivel',
#        'Quant_Banheiro_disponivel', 'Taman_Area_disponivel',
#        'Valor_Aluguel_disponivel', 'Valor_Condominio_disponivel',
#        'Valor_IPTU_disponivel', 'IDPerfil_Locacao',
#        'Quant_Quarto_desejado', 'Vagas_Garagem_desejado',
#        'Quant_banheiro_desejado', 'Taman_Area_desejado',
# ...

# %% [markdown]
# ## Consultas

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# QUERIES:
#
# 1°  Imovel melhor avaliado
# 2°  Prestadores de serviços melhor avaliado
# 3°  Qual tipo de serviço mais procurado
# 4°  Valor do aluguel somado ao condominio
# 5°  Imoveis com a maior quantidade de quarto
# 6°  Imoveis com a maior area
# 7°  Serviço prestado com menor valor
# 8°  Banco com o maior acionamento
# 9°  Imovel mais recomendado
# 10° Imovel com o maior custo (somando aluguel, condominio e IPTU)

# %% [markdown]
# Seleção das colunas desejada e ordenação decrescente.

# %%
# Imovel melhor avaliado

avaliacao_imovel = dados_df_selecionado[["Avaliacao_Imovel", "nome_locador"]].sort_values(by="Avaliacao_Imovel", ascending=False)

display(avaliacao_imovel)
# Out:
#     Avaliacao_Imovel         nome_locador
# 3                 10        Maria Eduadar
# 7                 10        Geronimo Alex
# 11                10        Roberto Naves
# 14                10         Debora Alves
# 0                  9          Maria Laura
# 4                  9         Olivia Belo
# 8                  9  Cristina Junqueira
# 12                 9        Luiz Claudio
# 13                 9      Carlos Brandão
# 1                  7           Jose Pedro
# 5                  7        Mathues Naves
# 6                  7         Soe Silveira
# 10                 7          Kely Maria
# 9                  5          Pedro Alves
# 2                  4           Paulo Jose

# %%
grafico = px.bar(avaliacao_imovel, x="nome_locador", y="Avaliacao_Imovel" )
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Seleção das colunas desejada e ordenação decrescente.

# %%
# Prestadores de serviços melhor avaliado

avaliacao_prestador = dados_df_selecionado[["Avaliacao_Servico","nome_prestador"]].sort_values(by="Avaliacao_Servico", ascending = False)


display(avaliacao_prestador)
# Out:
#     Avaliacao_Servico    nome_prestador
# 1                  10    Valerio Silva
# 5                  10         João Jose
# 6                  10    Paulo Henrique
# 10                 10     Vanessa Silva
# 11                 10    João Guilherme
# 0                   9        Pedro Abel
# 4                   9      Carla Gomes
# 7                   9      Gloria Maia
# 13                  9   Francisco Alves
# 14                  9     Daniele Gomes
# 9                   8  Gustavo Pereira
# 12                  8    Geralda Silva
# 3                   7     Ana Patricia
# 8                   7      Otavio Paulo
# 2                   5  Patricia Jacinto

# %%
grafico1 = px.area(avaliacao_prestador, x= "nome_prestador",  y= "Avaliacao_Servico")
grafico1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Seleção das colunas desejada e ordenação decrescente.

# %%
# Qual tipo de serviço mais procurado

servico_mais_procurado = dados_df_selecionado[["Tipo_Servico", "Avaliacao_Servico"]].sort_values(by="Avaliacao_Servico", ascending = False)


display(servico_mais_procurado)
# Out:
#               Tipo_Servico  Avaliacao_Servico
# 1      Bombeiro hidraulico                 10
# 5                Faxineira                 10
# 6                   Pintor                 10
# 10             Arquitetura                 10
# 11            Eletricista                  10
# 0                 Chaveiro                  9
# 4              Jardineiro                   9
# 7               Cozinheira                  9
# 13                Pedreiro                  9
# 14              Entregador                  9
# 9   Designer de interiores                  8
# 12               Encanador                  8
# 3             Carpinteiro                   7
# 8                    Baba                   7
# 2              Marcineiro                   5

# %%
grafico2 = px.bar(servico_mais_procurado, x = "Avaliacao_Servico", y= "Tipo_Servico", text_auto= True)

grafico2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Adição de uma nova coluna (soma aluguel mais Condominio)
# Seleção das colunas desejada e ordenação decrescente

# %%
#Valor do aluguel somado ao condominio ordenado do maior para o menor

dados_df_selecionado["soma_total_AC"] = dados_df_selecionado["Valor_Aluguel_disponivel"] + dados_df_selecionado["Valor_Condominio_disponivel"]

aluguel_condominio = dados_df_selecionado[["nome_locador", "Valor_Aluguel_disponivel", "Valor_Condominio_disponivel", "soma_total_AC"]].sort_values(by="soma_total_AC", ascending = False)
display(aluguel_condominio)
# Out:
#            nome_locador  Valor_Aluguel_disponivel  \
# 1            Jose Pedro                       900
# 13      Carlos Brandão                        900
# 5         Mathues Naves                       900
# 8   Cristina Junqueira                        800
# 12        Luiz Claudio                        800
# 7         Geronimo Alex                       750
# 14         Debora Alves                       750
# 0           Maria Laura                       600
# 10          Kely Maria                        650
# 9           Pedro Alves                       650
# 11        Roberto Naves                       600
# 3         Maria Eduadar                       600
# 2            Paulo Jose                       550
# 4          Olivia Belo                        550
# 6          Soe Silveira                       550
#
#     Valor_Condominio_disponivel  soma_total_AC
# 1                           250           1150
# 13                          250           1150
# ...

# %%
grafico3 = px.bar(aluguel_condominio, x = "nome_locador", y= ["Valor_Aluguel_disponivel", "Valor_Condominio_disponivel"], title = "Wide-Form Input" , text_auto= True )

grafico3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Seleção das colunas desejada e ordenação decrescente.

# %%
#Imoveis com a maior quantidade de quarto da região de BH 

quant_quarto = dados_df_selecionado [["nome_locador", "Quant_Quarto_disponivel", "Cidade_Locador" ]].sort_values(by="Quant_Quarto_disponivel", ascending = False)
display(quant_quarto)
# Out:
#            nome_locador  Quant_Quarto_disponivel      Cidade_Locador
# 1            Jose Pedro                        5            Contagem
# 12        Luiz Claudio                         5               Betim
# 3         Maria Eduadar                        4            Contagem
# 8   Cristina Junqueira                         4      Belo Horizonte
# 13      Carlos Brandão                         4  Ribeirão das Neves
# 2            Paulo Jose                        3               Betim
# 4          Olivia Belo                         3          Ponte Nova
# 5         Mathues Naves                        3            Contagem
# 7         Geronimo Alex                        3              Itaúna
# 9           Pedro Alves                        3               Betim
# 10          Kely Maria                         3             Itajubá
# 0           Maria Laura                        2      Belo Horizonte
# 6          Soe Silveira                        2               Betim
# ...

# %%
grafico4 = px.bar(quant_quarto, x = "nome_locador", y= "Quant_Quarto_disponivel", color= "Cidade_Locador", pattern_shape = "Cidade_Locador" ,  pattern_shape_sequence = [ "." ,  "x" ,  "+" ])

grafico4.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Seleção das colunas desejada e ordenação decrescente.

# %%
#Serviço prestado com menor valor 

sp_mmaior_valor = dados_df_selecionado[["Valor_Servico", "Tipo_Servico"]].sort_values(by="Valor_Servico", ascending = False)
display(sp_mmaior_valor)
# Out:
#     Valor_Servico            Tipo_Servico
# 2             200             Marcineiro
# 8             200                   Baba
# 12            200               Encanador
# 13            200                Pedreiro
# 1             150     Bombeiro hidraulico
# 6             150                  Pintor
# 11            150            Eletricista
# 14            150              Entregador
# 0             100                Chaveiro
# 3             100            Carpinteiro
# 7             100              Cozinheira
# 9             100  Designer de interiores
# 10            100             Arquitetura
# 5              90               Faxineira
# 4              80             Jardineiro

# %%
grafico5 = px.line(sp_mmaior_valor, x = "Tipo_Servico", y= "Valor_Servico", markers=True )
grafico5.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Banco Parceiros por região

banco_regiao =  dados_df_selecionado[["Nome_Banco", "Cidade_Banco"]].sort_values(by="Cidade_Banco")
display(banco_regiao)
# Out:
#            Nome_Banco          Cidade_Banco
# 10             Picpay              Aiuruoca
# 0                 PAN        Belo Horizonte
# 6               Itau         Belo Horizonte
# 7     Caixa ecnomica         Belo Horizonte
# 5           Santander              Contagem
# 11           Original              Contagem
# 12                BS2              Contagem
# 14               Neon           Divinópolis
# 8   Branco do brasil   Governador Valadares
# 1               Inter               Igarape
# 9              Semear    Ribeirão das Neves
# 4                  C6               Uberaba
# 3              Nubank              Varginha
# 2                 BMG               ibirite
# 13               Next               ibirite

# %%
grafico6 = px.funnel(banco_regiao, x="Cidade_Banco" , y= "Nome_Banco",  color="Nome_Banco")
grafico6.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Disponibilidade de Serviço

disponibilidade =  dados_df_selecionado[["Tipo_Servico", "Disponibilidade_serviço"]].sort_values(by="Disponibilidade_serviço")
display(disponibilidade)
# Out:
#               Tipo_Servico Disponibilidade_serviço
# 8                    Baba               2022-06-03
# 12               Encanador              2022-06-04
# 13                Pedreiro              2022-06-08
# 1      Bombeiro hidraulico              2022-06-10
# 14              Entregador              2022-06-10
# 3             Carpinteiro               2022-06-12
# 10             Arquitetura              2022-06-15
# 5                Faxineira              2022-06-19
# 4              Jardineiro               2022-06-25
# 7               Cozinheira              2022-07-01
# 11            Eletricista               2022-07-10
# 9   Designer de interiores              2022-09-14
# 0                 Chaveiro              2022-09-15
# 6                   Pintor              2022-09-20
# 2              Marcineiro               2022-10-05

# %%
grafico7 = px.box(disponibilidade, x= "Tipo_Servico", y= "Disponibilidade_serviço")
grafico7.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Relato das dificuldades encontradas.

# %% [markdown]
# Nessa etapa a grande dificuldade foi a exportação e importação da base de dados para o  jupyter notebook.
# Nas etapas anteriores criamos uma base de dados no MySQL, gerando várias tabelas com dados variado.
# Ao criar o notebook para dar início a essa etapa, era necessário a importação da base de dados e foram aplicadas diversas tentativas de importação sem sucesso como: compilar os dados em uma só planilha, importar a pasta com todas as planilhas e até mesmo usar por conexão os dados direto do MySQL, mas as alternativas apresentaram erros ou dados faltantes.
# Como medida de contorno exportamos todas as tabelas do MySQL e compilamos manualmente todos os dados em uma planilha no formato Excel (XLSM).
# Importamos essa tabela para Jupyter notebook e seguimos sem maiores dificuldades.
